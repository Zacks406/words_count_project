# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("pokemon_data.csv")

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
sns.boxplot(data = df, x = "Attack")
# Out:
# <Axes: xlabel='Attack'>

# %%
df.loc[df["Attack"] > 170]
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True
# 232       40      105     75           2      False
# 424      150       90     90           3       True
# 426      180      100    115           3       True
# 429      180       20    150           3       True

# %%
df.query("Attack > 150")
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 137  127        PinsirMega Pinsir      Bug    Flying   65     155      120
# 141  130    GyaradosMega Gyarados    Water      Dark   95     155      109
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 268  248  TyranitarMega Tyranitar     Rock      Dark  100     164      150
# 279  257    BlazikenMega Blaziken     Fire  Fighting   80     160       80
# 313  289                  Slaking   Normal       NaN  150     160      100
# 387  354      BanetteMega Banette    Ghost       NaN   64     165       75
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df[df["Speed"] <= 10]
# Out:
#        #       Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213    Shuckle     Bug   Rock   20      10      230       10      230
# 359  328   Trapinch  Ground    NaN   45     100       45       45       45
# 486  438     Bonsly    Rock    NaN   50      80       95       10       45
# 495  446   Munchlax  Normal    NaN  135      85       40       40       85
# 658  597  Ferroseed   Grass  Steel   44      50       91       24       86
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 359     10           3      False
# 486     10           4      False
# 495      5           4      False
# 658     10           5      False

# %%
df["Speed"] <= 10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Speed, Length: 800, dtype: bool

# %%
df[df["Sp. Def"] <= 25].sort_values(by = "Sp. Def")
# Out:
#        #                Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 13    10            Caterpie      Bug     NaN   45      30       35       20
# 16    13              Weedle      Bug  Poison   40      35       30       20
# 188  174           Igglybuff   Normal   Fairy   90      30       15       40
# 139  129            Magikarp    Water     NaN   20      10       55       15
# 429  386  DeoxysAttack Forme  Psychic     NaN   50     180       20      180
# 347  318            Carvanha    Water    Dark   45      90       20       65
# 317  293             Whismur   Normal     NaN   64      51       23       51
# 14    11             Metapod      Bug     NaN   50      20       55       25
# 125  116              Horsea    Water     NaN   30      40       70       70
# 106   98              Krabby    Water     NaN   30     105       90       25
# 97    90            Shellder    Water     NaN   30      65      100       45
# ...

# %%
(df[df["Sp. Def"] <= 25]).sum()
# Out:
# #                                                          3607
# Name          CaterpieMetapodWeedleKakunaJigglypuffShellderK...
# Type 1        BugBugBugBugNormalWaterWaterWaterWaterNormalWa...
# Type 2                         PoisonPoisonFairyFairyGroundDark
# HP                                                          902
# Attack                                                      951
# Defense                                                     863
# Sp. Atk                                                     753
# Sp. Def                                                     418
# Speed                                                       763
# Generation                                                   39
# Legendary                                                     1
# dtype: object

# %%
(df["Sp. Def"] <= 25).sum()
# Out:
# np.int64(18)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
Legendary_df = [df["Legendary"] == True]

# %%
Legendary_df
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  795     True
#  796     True
#  797     True
#  798     True
#  799     True
#  Name: Legendary, Length: 800, dtype: bool]

# %%
(df["Legendary"] == True).sum()
# Out:
# np.int64(65)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
ax = sns.scatterplot(data = df, x = "Defense", y = "Attack")
ax.annotate("Who is this guy?", xy=(155, 10), xytext=(155, 10) )
# Out:
# Text(155, 10, 'Who is this guy?')

# %%
##arrowprops = dic(arrowstyle = "->", color = "red")

# %%
df.sort_values(by = ["Defense", "Attack"], ascending = [False, True])
# Out:
#        #                 Name    Type 1   Type 2   HP  Attack  Defense  \
# 230  213              Shuckle       Bug     Rock   20      10      230
# 224  208  SteelixMega Steelix     Steel   Ground   75     125      230
# 333  306    AggronMega Aggron     Steel      NaN   70     140      230
# 223  208              Steelix     Steel   Ground   75      85      200
# 414  377             Regirock      Rock      NaN   80     100      200
# ..   ...                  ...       ...      ...  ...     ...      ...
# 257  238             Smoochum       Ice  Psychic   45      30       15
# 186  172                Pichu  Electric      NaN   20      40       15
# 261  242              Blissey    Normal      NaN  255      10       10
# 121  113              Chansey    Normal      NaN  250       5        5
# 488  440              Happiny    Normal      NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 230       10      230      5           2      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df[(df["Type 1"] == "Fire") & (df["Type 2"] == "Flying")]
# Out:
#        #                       Name Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard   Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# 158  146                    Moltres   Fire  Flying   90     100       90
# 270  250                      Ho-oh   Fire  Flying  106     130       90
# 730  662                Fletchinder   Fire  Flying   62      73       55
# 731  663                 Talonflame   Fire  Flying   78      81       71
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6        109       85    100           1      False
# 8        159      115    100           1      False
# 158      125       85     90           1       True
# 270      110      154     90           2       True
# 730       56       52     84           6      False
# 731       74       69    126           6      False

# %%
(df["Type 1"] == "Fire").sum() & (df["Type 2"] == "Flying").sum()
# Out:
# np.int64(32)

# %%
df.query("`Type 1` == 'Fire' and `Type 2` == 'Flying'")
# Out:
#        #                       Name Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard   Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# 158  146                    Moltres   Fire  Flying   90     100       90
# 270  250                      Ho-oh   Fire  Flying  106     130       90
# 730  662                Fletchinder   Fire  Flying   62      73       55
# 731  663                 Talonflame   Fire  Flying   78      81       71
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6        109       85    100           1      False
# 8        159      115    100           1      False
# 158      125       85     90           1       True
# 270      110      154     90           2       True
# 730       56       52     84           6      False
# 731       74       69    126           6      False

# %%
(df["Type 1"] == "Poison").sum() | (df["Type 2"] == "Poison").sum()
# Out:
# np.int64(62)

# %%
df[df["Type 1"] == "Ice"].sort_values(by = "Defense", ascending = False)
# Out:
#        #               Name Type 1   Type 2   HP  Attack  Defense  Sp. Atk  \
# 789  713            Avalugg    Ice      NaN   95     117      184       44
# 522  471            Glaceon    Ice      NaN   65      60      110      130
# 156  144           Articuno    Ice   Flying   90      85      100       95
# 415  378             Regice    Ice      NaN   80      50      100      100
# 400  365            Walrein    Ice    Water  110      80       90       95
# 645  584          Vanilluxe    Ice      NaN   71      95       85      110
# 788  712           Bergmite    Ice      NaN   55      69       85       32
# 239  221          Piloswine    Ice   Ground  100     100       80       60
# 675  614            Beartic    Ice      NaN   95     110       80       70
# 396  362             Glalie    Ice      NaN   80      80       80       80
# 524  473          Mamoswine    Ice   Ground  110     130       80       70
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.loc[
    (df["Type 1"] == "Ice") & 
    (df["Defense"] == df.loc[df["Type 1"] == "Ice", "Defense"].max())
]
# Out:
#        #     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 789  713  Avalugg    Ice    NaN  95     117      184       44       46     28
#
#      Generation  Legendary
# 789           6      False

# %%
df.loc[df["Type 1"] == "Ice", "Defense"]
# Out:
# 133     35
# 156    100
# 238     40
# 239     80
# 243     45
# 257     15
# 395     50
# 396     80
# 397     80
# 398     50
# 399     70
# 400     90
# 415    100
# 522    110
# 524     80
# 530     70
# 643     50
# 644     65
# 645     85
# 674     40
# 675     80
# 676     30
# 788     85
# 789    184
# Name: Defense, dtype: int64

# %%
df[df["Type 1"] == "Ice"]
# Out:
#        #               Name Type 1   Type 2   HP  Attack  Defense  Sp. Atk  \
# 133  124               Jynx    Ice  Psychic   65      50       35      115
# 156  144           Articuno    Ice   Flying   90      85      100       95
# 238  220             Swinub    Ice   Ground   50      50       40       30
# 239  221          Piloswine    Ice   Ground  100     100       80       60
# 243  225           Delibird    Ice   Flying   45      55       45       65
# 257  238           Smoochum    Ice  Psychic   45      30       15       85
# 395  361            Snorunt    Ice      NaN   50      50       50       50
# 396  362             Glalie    Ice      NaN   80      80       80       80
# 397  362  GlalieMega Glalie    Ice      NaN   80     120       80      120
# 398  363             Spheal    Ice    Water   70      40       50       55
# 399  364             Sealeo    Ice    Water   90      60       70       75
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.loc[df["Legendary"] == True]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df["Legendary"], "Type 1"]
# Out:
# 156         Ice
# 157    Electric
# 158        Fire
# 162     Psychic
# 163     Psychic
#          ...
# 795        Rock
# 796        Rock
# 797     Psychic
# 798     Psychic
# 799        Fire
# Name: Type 1, Length: 65, dtype: str

# %%
df.loc[df["Legendary"], "Type 1"].value_counts()
# Out:
# Type 1
# Psychic     14
# Dragon      12
# Fire         5
# Electric     4
# Water        4
# Rock         4
# Steel        4
# Ground       4
# Grass        3
# Ice          2
# Normal       2
# Ghost        2
# Dark         2
# Flying       2
# Fairy        1
# Name: count, dtype: int64

# %%
df.loc[df["Legendary"], "Type 1"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Type 1'>

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
(df[df["Type 1"] == "Water"])
# Out:
#        #                     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 9      7                 Squirtle  Water    NaN  44      48       65       50
# 10     8                Wartortle  Water    NaN  59      63       80       65
# 11     9                Blastoise  Water    NaN  79      83      100       85
# 12     9  BlastoiseMega Blastoise  Water    NaN  79     103      120      135
# 59    54                  Psyduck  Water    NaN  50      52       48       65
# ..   ...                      ...    ...    ...  ..     ...      ...      ...
# 724  656                  Froakie  Water    NaN  41      56       40       62
# 725  657                Frogadier  Water    NaN  54      63       52       83
# 726  658                 Greninja  Water   Dark  72      95       67      103
# 762  692                Clauncher  Water    NaN  50      53       62       58
# 763  693                Clawitzer  Water    NaN  71      73       88      120
#
# ...

# %%
 df["Generation"].value_counts(sort = False)
# Out:
# Generation
# 1    166
# 2    106
# 3    160
# 4    121
# 5    165
# 6     82
# Name: count, dtype: int64

# %%
 df["Generation"].value_counts(sort = False).plot(kind = "bar")
# Out:
# <Axes: xlabel='Generation'>

# %%
df.loc[
    (df["Type 1"] == "Water") & 
    df["Generation"].isin([1,2,3])
].sort_values(by = "HP", ascending = False).head()
# Out:
#        #      Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 351  321   Wailord  Water       NaN  170      90       45       90       45
# 142  131    Lapras  Water       Ice  130      85       80       85       95
# 145  134  Vaporeon  Water       NaN  130      65       60      110       95
# 350  320   Wailmer  Water       NaN  130      70       35       70       35
# 185  171   Lanturn  Water  Electric  125      58       58       76       76
#
#      Speed  Generation  Legendary
# 351     60           3      False
# 142     60           1      False
# 145     65           1      False
# 350     60           3      False
# 185     67           2      False

# %%
df.loc[
    ((df["Type 1"] == "Dragon") | (df["Type 2"] == "Dragon")) & (df["Generation"].isin([5,6]))
].sort_values(by = "HP", ascending = False)
# Out:
#        #                Name  Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 711  646  KyuremBlack Kyurem  Dragon       Ice  125     170      100      120
# 712  646  KyuremWhite Kyurem  Dragon       Ice  125     120       90      170
# 710  646              Kyurem  Dragon       Ice  125     130       90      130
# 794  718    Zygarde50% Forme  Dragon    Ground  108     100      121       81
# 706  643            Reshiram  Dragon      Fire  100     120      100      150
# 707  644              Zekrom  Dragon  Electric  100     150      120      120
# 696  635           Hydreigon    Dark    Dragon   92     105       90      125
# 776  706              Goodra  Dragon       NaN   90     100       70      110
# 791  715             Noivern  Flying    Dragon   85      70       80       97
# 767  697           Tyrantrum    Rock    Dragon   82     121      119       69
# 682  621           Druddigon  Dragon       NaN   77     120       90       60
# ...

# %%
df.query(
    "(`Type 1` == 'Dragon' or `Type 2` == 'Dragon') and (Generation in [5,6])").sort_values(by = "HP", ascending = False)
# Out:
#        #                Name  Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 711  646  KyuremBlack Kyurem  Dragon       Ice  125     170      100      120
# 712  646  KyuremWhite Kyurem  Dragon       Ice  125     120       90      170
# 710  646              Kyurem  Dragon       Ice  125     130       90      130
# 794  718    Zygarde50% Forme  Dragon    Ground  108     100      121       81
# 706  643            Reshiram  Dragon      Fire  100     120      100      150
# 707  644              Zekrom  Dragon  Electric  100     150      120      120
# 696  635           Hydreigon    Dark    Dragon   92     105       90      125
# 776  706              Goodra  Dragon       NaN   90     100       70      110
# 791  715             Noivern  Flying    Dragon   85      70       80       97
# 767  697           Tyrantrum    Rock    Dragon   82     121      119       69
# 682  621           Druddigon  Dragon       NaN   77     120       90       60
# ...

# %%
power = df.query("(Attack > 100) and (`Type 1` == 'Fire')")
power
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 147  136                    Flareon   Fire       NaN   65     130       60
# 263  244                      Entei   Fire       NaN  115     115       85
# 270  250                      Ho-oh   Fire    Flying  106     130       90
# 278  257                   Blaziken   Fire  Fighting   80     120       70
# 279  257      BlazikenMega Blaziken   Fire  Fighting   80     160       80
# 354  323      CameruptMega Camerupt   Fire    Ground   70     120      100
# 437  392                  Infernape   Fire  Fighting   76     104       71
# 559  500                     Emboar   Fire  Fighting  110     123       65
# ...

# %%
 df.query("(Attack > 100) and (`Type 1` == 'Fire')")
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 147  136                    Flareon   Fire       NaN   65     130       60
# 263  244                      Entei   Fire       NaN  115     115       85
# 270  250                      Ho-oh   Fire    Flying  106     130       90
# 278  257                   Blaziken   Fire  Fighting   80     120       70
# 279  257      BlazikenMega Blaziken   Fire  Fighting   80     160       80
# 354  323      CameruptMega Camerupt   Fire    Ground   70     120      100
# 437  392                  Infernape   Fire  Fighting   76     104       71
# 559  500                     Emboar   Fire  Fighting  110     123       65
# ...

# %%
df[(df["Type 1"] == "Water") & (df["Type 2"] == "Flying")]
# Out:
#        #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 140  130  Gyarados  Water  Flying  95     125       79       60      100
# 244  226   Mantine  Water  Flying  65      40       70       80      140
# 301  278   Wingull  Water  Flying  40      30       30       55       30
# 302  279  Pelipper  Water  Flying  60      50      100       85       70
# 508  458   Mantyke  Water  Flying  45      20       50       60      120
# 641  580  Ducklett  Water  Flying  62      44       50       44       50
# 642  581    Swanna  Water  Flying  75      87       63       87       63
#
#      Speed  Generation  Legendary
# 140     81           1      False
# 244     70           2      False
# 301     85           3      False
# 302     65           3      False
# 508     50           4      False
# 641     55           5      False
# 642     98           5      False

# %%
df.loc[((df["Legendary"]) & (df["Type 1"] == "Fire")), ["Attack", "Generation"] ]
# Out:
#      Attack  Generation
# 158     100           1
# 263     115           2
# 270     130           2
# 542      90           4
# 799     110           6
